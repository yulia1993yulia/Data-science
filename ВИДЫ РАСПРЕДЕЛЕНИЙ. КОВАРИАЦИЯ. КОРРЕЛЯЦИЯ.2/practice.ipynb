# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('final_data.csv')
data.head(5)
# Out:
#    Unnamed: 0                             address  \
# 0           2  Address: 1160 Mission Street #2007
# 1           5       Address: 260 King Street #475
# 2           7     Address: 560 Missouri Street #B
# 3           9        Address: 350 Missouri Street
# 4          11         Address: 3658 Folsom Street
#
#                                                 info  \
# 0   San FranciscoSales price: 1300000Sales date: ...
# 1   San FranciscoSales price: 750000Sales date: 0...
# 2   San FranciscoSales price: 1495000Sales date: ...
# 3   San FranciscoSales price: 2700000Sales date: ...
# 4   San FranciscoSales price: 1530000Sales date: ...
#
#                    z_address  bathrooms  bedrooms  finishedsqft lastsolddate  \
# 0  1160 Mission St UNIT 2007        2.0       2.0        1043.0   02/17/2016
# 1       260 King St UNIT 475        1.0       1.0         903.0   02/17/2016
# 2        560 Missouri St # B        4.0       3.0        1425.0   02/17/2016
# ...

# %%
data = data[['bathrooms', 'bedrooms',  'finishedsqft', 'lastsoldprice', 'zestimate']]
data.head(5)
# Out:
#    bathrooms  bedrooms  finishedsqft  lastsoldprice  zestimate
# 0        2.0       2.0        1043.0      1300000.0  1167508.0
# 1        1.0       1.0         903.0       750000.0   823719.0
# 2        4.0       3.0        1425.0      1495000.0  1708594.0
# 3        3.0       3.0        2231.0      2700000.0  2411236.0
# 4        3.0       3.0        1300.0      1530000.0  1918539.0

# %%
data[['bathrooms', 'bedrooms']].cov()
# Out:
#            bathrooms  bedrooms
# bathrooms   1.096959  0.972120
# bedrooms    0.972120  1.688589

# %%
data[['bathrooms', 'bedrooms']].var()
# Out:
# bathrooms    1.096959
# bedrooms     1.688589
# dtype: float64

# %%
data[['bathrooms', 'bedrooms']].corr()
# Out:
#            bathrooms  bedrooms
# bathrooms    1.00000   0.71427
# bedrooms     0.71427   1.00000

# %%
data[['bathrooms', 'bedrooms']].corr('spearman')
# Out:
#            bathrooms  bedrooms
# bathrooms   1.000000  0.694795
# bedrooms    0.694795  1.000000

# %%
data.corr()
# Out:
#                bathrooms  bedrooms  finishedsqft  lastsoldprice  zestimate
# bathrooms       1.000000  0.714270      0.719096       0.536880   0.603158
# bedrooms        0.714270  1.000000      0.697461       0.395478   0.477676
# finishedsqft    0.719096  0.697461      1.000000       0.647208   0.758493
# lastsoldprice   0.536880  0.395478      0.647208       1.000000   0.876939
# zestimate       0.603158  0.477676      0.758493       0.876939   1.000000

# %%
data.corr('spearman')
# Out:
#                bathrooms  bedrooms  finishedsqft  lastsoldprice  zestimate
# bathrooms       1.000000  0.694795      0.721145       0.524783   0.600274
# bedrooms        0.694795  1.000000      0.773529       0.447761   0.529980
# finishedsqft    0.721145  0.773529      1.000000       0.633977   0.743216
# lastsoldprice   0.524783  0.447761      0.633977       1.000000   0.838328
# zestimate       0.600274  0.529980      0.743216       0.838328   1.000000

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(data.corr('spearman'))
plt.show()
